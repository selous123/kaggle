# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

data = pd.read_csv("train.csv")

#print data.head(3)

#print data[0:1]['Cabin']

#print data.info()


# print type(data.values)

#print data.describe()
#print "hello:{}".format (data.values.dtype)

#print data[0:3]["Survived"]

#print data.iat[0,3]



#print "{}".format(data.iloc[0:2,:])

#d = data.groupby(["Survived","Sex"]).size().reset_index().rename(columns={'Survived':'survived',"Sex":"sex",0:"data"})

#print d
#sns.barplot(x="sex",y="data",hue='survived',data=d)

#plt.show()

data1 = data.loc[:,["Survived","Fare","Age","Sex",'Pclass']].dropna(how='any')


data_die = data1[data1["Survived"]==0]
data_live = data1[data1["Survived"]==1]

#fig,ax = plt.subplots()

# ax = sns.regplot(x="Fare", y="Age", scatter=True,data=data_die);
# ax = sns.regplot(x="Fare", y="Age", scatter=True,data=data_live,marker='+');

sns.factorplot(x="Pclass",y='Age',kind='swarm',hue='Survived',col="Sex",data=data1,dodge=True)

plt.show()
#data

# %%
from __future__ import division
import math




int(math.ceil(3 / 2))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
ts = pd.Series(np.random.randn(100000), index=pd.date_range('1/1/2000', periods=100000))

df = pd.DataFrame(np.random.randn(100000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])

# df1 = df.cumsum(axis=0)

# print df.sum(1)
# ts.value_counts()

#df = df.cumsum()

sns.distplot(df["A"])

plt.show()

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                       'B' : ['A', 'B', 'C'] * 4,
                       'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D' : np.random.randn(12),
                       'E' : np.random.randn(12)})
print df

pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])

# %%
#coding:utf-8
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
data = pd.read_csv("train.csv")

data1 = data.loc[:,["Age","Pclass"]] 

data1 = data1.dropna(how='any')
#print type(data.Age)

sns.set()
fig, axs = plt.subplots()

ax = sns.kdeplot(data1.Age[data1.Pclass == 3])
ax = sns.kdeplot(data1.Age[data1.Pclass == 1])
ax = sns.kdeplot(data1.Age[data1.Pclass == 2])


plt.legend((u'1等舱', u'2等舱',u'3等舱'),loc='best')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw the two density plots
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                 cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                 cmap="Blues", shade=True, shade_lowest=False)

# Add labels to the plot
# red = sns.color_palette("Reds")[-2]
# blue = sns.color_palette("Blues")[-2]
# ax.text(2.5, 8.2, "virginica", size=16, color=blue)
# ax.text(3.8, 4.5, "setosa", size=16, color=red)

plt.show()

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sns.set(color_codes=True)
sns.set_style("ticks")
sinplot()

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
tips = sns.load_dataset("tips")

#f, ax = plt.subplots(figsize=(5.4,5.4))
#sns.regplot(x="total_bill", y="tip", scatter=True,data=tips,marker='+',ax=ax);
# sns.regplot(x="total_bill", y="tip", data=tips,ax=ax);
# sns.regplot(x="total_bill", y="tip", data=tips,ax=ax);
# sns.regplot(x="total_bill", y="tip", data=tips,ax=ax);
#sns.lmplot(x="total_bill", y="tip", data=tips);
g = sns.lmplot(x="size", y="total_bill", col="day",hue="day",
                data=tips, aspect=.4, x_jitter=.1)

plt.show()

#tips
